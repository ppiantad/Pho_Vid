# %%
'''

This code is designed to filter data from a .csv file generated by ABET software based upon user input

Generating a data table and filtering is the first step to aligning behavioral epochs with calcium imaging data

'''

# %%
pwd
# Out:
# 'C:\\Users\\Patrick\\Pho_Vid'

# %%
import pandas as pd
import numpy as np

# %%
# read in behavioral data as .csv
# eventually will write this more flexibly as a function (so users can give a filename externally)
data = pd.read_csv("74 12042019.csv")

# %%
#Time values < 0 are housekeeping variables reported by the software. Safe to filter these out so they do not get counted as trials, etc.
filter_time_zero = data.Evnt_Time != 0
filter_time_zero.values
data = data[filter_time_zero]

# %%
#logic for indicating new trials, adds a new column to the data frame (data) that counts the number of trials based on trial starts
is_new_trial = (data.Item_Name == "Forced-Choice Trials Begin") | (data.Item_Name == "Free-Choice Trials begin")
data["is_new_trial"] = is_new_trial
data["is_new_trial"].value_counts()
data["trial_num"] = np.cumsum(data["is_new_trial"])
data["trial_num"].max()
# Out:
# 164

# %%
is_forced_trial = (data.Item_Name == "Forced-Choice Trials Begin")
data["Forced-Choice Trial"] = is_forced_trial
is_forced_trial.value_counts()
# Out:
# False    9540
# True       51
# Name: Item_Name, dtype: int64

# %%
data.head(500)
# Out:
#      Evnt_Time  Evnt_ID                          Evnt_Name  \
# 74       0.022        1                    Condition Event
# 75       0.022        3                    Output On Event
# 76       0.022        3                    Output On Event
# 77       0.022        3                    Output On Event
# 78       0.022        3                    Output On Event
# 79       0.022       21                 Group Change Event
# 80       0.035       39         Input Transition Off Event
# 81       0.047       38          Input Transition On Event
# 82       2.327       38          Input Transition On Event
# 83       2.443       39         Input Transition Off Event
# 84       2.493       38          Input Transition On Event
# 85       3.167       39         Input Transition Off Event
# 86       3.195       38          Input Transition On Event
# 87       3.211       39         Input Transition Off Event
# 88       6.924       38          Input Transition On Event
# 89       7.084       39         Input Transition Off Event
# 90       7.095       38          Input Transition On Event
# 91       8.315       39         Input Transition Off Event
# 92       8.321       38          Input Transition On Event
# 93       8.331       39         Input Transition Off Event
# 94       8.510       38          Input Transition On Event
# 95       8.571       39         Input Transition Off Event
# 96       8.597       38          Input Transition On Event
# 97       8.614       39         Input Transition Off Event
# 98      15.645       38          Input Transition On Event
# 99      15.724       39         Input Transition Off Event
# 100     15.806       38          Input Transition On Event
# 101     16.601       39         Input Transition Off Event
# 102     31.823       38          Input Transition On Event
# 103     32.093       39         Input Transition Off Event
# ..         ...      ...                                ...
# 544    181.819       21                 Group Change Event
# 545    181.819        1                    Condition Event
# 546    181.819       16                     Variable Event
# 547    181.819       21                 Group Change Event
# 548    183.999       39         Input Transition Off Event
# 549    184.000        1                    Condition Event
# 550    184.000       16                     Variable Event
# 551    184.000       21                 Group Change Event
# 552    184.000        1                    Condition Event
# 553    184.000       16                     Variable Event
# 554    184.000       21                 Group Change Event
# 555    187.367       38          Input Transition On Event
# 556    187.368        1                    Condition Event
# 557    187.368        4                   Output Off Event
# 558    187.368       32            Whisker - Display Image
# 559    187.368       29                        Timer Event
# 560    187.368       32            Whisker - Display Image
# 561    187.368       21                 Group Change Event
# 562    188.325       39         Input Transition Off Event
# 563    189.131       30                   Touch Down Event
# 564    189.132        1                    Condition Event
# 565    189.132        3                    Output On Event
# 566    189.132        7                 Pulse Output Event
# 567    189.132        7                 Pulse Output Event
# 568    189.132       34  Whisker - Clear Image by Position
# 569    189.132       32            Whisker - Display Image
# 570    189.132       32            Whisker - Display Image
# 571    189.132       16                     Variable Event
# 572    189.132       19           List Change - Next Value
# 573    189.132       16                     Variable Event
#
#                                  Item_Name  Alias_Name  Group_ID  Num_Args  \
# 74                  set HL, WN_Off, Sound2         NaN         0         0
# 75                           HouseLight #1         NaN         0         0
# 76                                Sound #2         NaN         0         0
# 77                      White_Noise_Off #1         NaN         0         0
# 78                                Laser #1         NaN         0         0
# 79                            Group Change         NaN         0         1
# 80                              FIRBeam #1         NaN         2         0
# 81                              FIRBeam #1         NaN         2         0
# 82                                 Tray #1         NaN         2         0
# 83                                 Tray #1         NaN         2         0
# 84                                 Tray #1         NaN         2         0
# 85                                 Tray #1         NaN         2         0
# 86                                 Tray #1         NaN         2         0
# 87                                 Tray #1         NaN         2         0
# 88                                 Tray #1         NaN         2         0
# 89                                 Tray #1         NaN         2         0
# 90                                 Tray #1         NaN         2         0
# 91                                 Tray #1         NaN         2         0
# 92                                 Tray #1         NaN         2         0
# 93                                 Tray #1         NaN         2         0
# 94                                 Tray #1         NaN         2         0
# 95                                 Tray #1         NaN         2         0
# 96                                 Tray #1         NaN         2         0
# 97                                 Tray #1         NaN         2         0
# 98                                 Tray #1         NaN         2         0
# 99                                 Tray #1         NaN         2         0
# 100                                Tray #1         NaN         2         0
# 101                                Tray #1         NaN         2         0
# 102                                Tray #1         NaN         2         0
# 103                                Tray #1         NaN         2         0
# ..                                     ...         ...       ...       ...
# 544                           Group Change         NaN         3         1
# 545         Are we in Forced_Choice Trials         NaN         4         0
# 546                      FreeChoice_trials         NaN         4         1
# 547                           Group Change         NaN         4         1
# 548                                Tray #1         NaN         5         0
# 549              Set Trial (correct image)         NaN         5         0
# 550                    Forced_img_position         NaN         5         1
# 551                           Group Change         NaN         5         1
# 552                            Blank Right         NaN         6         0
# 553                  Forced_blank_position         NaN         6         1
# 554                           Group Change         NaN         6         1
# 555                                Tray #1         NaN         7         0
# 556             Forced-Choice Trials Begin         NaN         7         0
# 557                           TrayLight #1         NaN         7         0
# 558  Bussey Mouse Operant Mode 2 x 1 x low      Images         7         2
# 559                     Presentation_timer         NaN         7         1
# 560  Bussey Mouse Operant Mode 2 x 1 x low  Background         7         2
# 561                           Group Change         NaN         7         1
# 562                                Tray #1         NaN         9         0
# 563  Bussey Mouse Operant Mode 2 x 1 x low         NaN         9         2
# 564              S1-Forced-image touch=big         NaN         9         0
# 565                           TrayLight #1         NaN         9         0
# 566                              Feeder #2         NaN         9         1
# 567                            Sound_On #1         NaN         9         1
# 568  Bussey Mouse Operant Mode 2 x 1 x low         NaN         9         2
# 569  Bussey Mouse Operant Mode 2 x 1 x low  Background         9         2
# 570  Bussey Mouse Operant Mode 2 x 1 x low  Background         9         2
# 571                           shock_on_off         NaN         9         1
# 572                S1_0_forcedchoice_shock         NaN         9         2
# 573                         _Trial_Counter         NaN         9         1
#
#      Arg1_Name  Arg1_Value Arg2_Name  Arg2_Value Arg3_Name  Arg3_Value  \
# 74         NaN         NaN       NaN         NaN       NaN         NaN
# 75         NaN         NaN       NaN         NaN       NaN         NaN
# 76         NaN         NaN       NaN         NaN       NaN         NaN
# 77         NaN         NaN       NaN         NaN       NaN         NaN
# 78         NaN         NaN       NaN         NaN       NaN         NaN
# 79   New Group         2.0       NaN         NaN       NaN         NaN
# 80         NaN         NaN       NaN         NaN       NaN         NaN
# 81         NaN         NaN       NaN         NaN       NaN         NaN
# 82         NaN         NaN       NaN         NaN       NaN         NaN
# 83         NaN         NaN       NaN         NaN       NaN         NaN
# 84         NaN         NaN       NaN         NaN       NaN         NaN
# 85         NaN         NaN       NaN         NaN       NaN         NaN
# 86         NaN         NaN       NaN         NaN       NaN         NaN
# 87         NaN         NaN       NaN         NaN       NaN         NaN
# 88         NaN         NaN       NaN         NaN       NaN         NaN
# 89         NaN         NaN       NaN         NaN       NaN         NaN
# 90         NaN         NaN       NaN         NaN       NaN         NaN
# 91         NaN         NaN       NaN         NaN       NaN         NaN
# 92         NaN         NaN       NaN         NaN       NaN         NaN
# 93         NaN         NaN       NaN         NaN       NaN         NaN
# 94         NaN         NaN       NaN         NaN       NaN         NaN
# 95         NaN         NaN       NaN         NaN       NaN         NaN
# 96         NaN         NaN       NaN         NaN       NaN         NaN
# 97         NaN         NaN       NaN         NaN       NaN         NaN
# 98         NaN         NaN       NaN         NaN       NaN         NaN
# 99         NaN         NaN       NaN         NaN       NaN         NaN
# 100        NaN         NaN       NaN         NaN       NaN         NaN
# 101        NaN         NaN       NaN         NaN       NaN         NaN
# 102        NaN         NaN       NaN         NaN       NaN         NaN
# 103        NaN         NaN       NaN         NaN       NaN         NaN
# ..         ...         ...       ...         ...       ...         ...
# 544  New Group         4.0       NaN         NaN       NaN         NaN
# 545        NaN         NaN       NaN         NaN       NaN         NaN
# 546      Value         0.0       NaN         NaN       NaN         NaN
# 547  New Group         5.0       NaN         NaN       NaN         NaN
# 548        NaN         NaN       NaN         NaN       NaN         NaN
# 549        NaN         NaN       NaN         NaN       NaN         NaN
# 550      Value         1.0       NaN         NaN       NaN         NaN
# 551  New Group         6.0       NaN         NaN       NaN         NaN
# 552        NaN         NaN       NaN         NaN       NaN         NaN
# 553      Value         2.0       NaN         NaN       NaN         NaN
# 554  New Group         7.0       NaN         NaN       NaN         NaN
# 555        NaN         NaN       NaN         NaN       NaN         NaN
# 556        NaN         NaN       NaN         NaN       NaN         NaN
# 557        NaN         NaN       NaN         NaN       NaN         NaN
# 558   Position         1.0   Image 1         0.0       NaN         NaN
# 559      Value         0.0       NaN         NaN       NaN         NaN
# 560   Position         2.0   Image 1         0.0       NaN         NaN
# 561  New Group         9.0       NaN         NaN       NaN         NaN
# 562        NaN         NaN       NaN         NaN       NaN         NaN
# 563   Position         1.0   Image 1         0.0       NaN         NaN
# 564        NaN         NaN       NaN         NaN       NaN         NaN
# 565        NaN         NaN       NaN         NaN       NaN         NaN
# 566   Duration         1.2       NaN         NaN       NaN         NaN
# 567   Duration         1.0       NaN         NaN       NaN         NaN
# 568   Position         1.0       NaN        -1.0       NaN         NaN
# 569   Position         2.0   Image 1         0.0       NaN         NaN
# 570   Position         1.0   Image 1         0.0       NaN         NaN
# 571      Value         0.0       NaN         NaN       NaN         NaN
# 572      Index         4.0     Value         0.0       NaN         NaN
# 573      Value         7.0       NaN         NaN       NaN         NaN
#
#     Arg4_Name  Arg4_Value Arg5_Name  Arg5_Value  is_new_trial  trial_num  \
# 74        NaN         NaN       NaN         NaN         False          0
# 75        NaN         NaN       NaN         NaN         False          0
# 76        NaN         NaN       NaN         NaN         False          0
# 77        NaN         NaN       NaN         NaN         False          0
# 78        NaN         NaN       NaN         NaN         False          0
# 79        NaN         NaN       NaN         NaN         False          0
# 80        NaN         NaN       NaN         NaN         False          0
# 81        NaN         NaN       NaN         NaN         False          0
# 82        NaN         NaN       NaN         NaN         False          0
# 83        NaN         NaN       NaN         NaN         False          0
# 84        NaN         NaN       NaN         NaN         False          0
# 85        NaN         NaN       NaN         NaN         False          0
# 86        NaN         NaN       NaN         NaN         False          0
# 87        NaN         NaN       NaN         NaN         False          0
# 88        NaN         NaN       NaN         NaN         False          0
# 89        NaN         NaN       NaN         NaN         False          0
# 90        NaN         NaN       NaN         NaN         False          0
# 91        NaN         NaN       NaN         NaN         False          0
# 92        NaN         NaN       NaN         NaN         False          0
# 93        NaN         NaN       NaN         NaN         False          0
# 94        NaN         NaN       NaN         NaN         False          0
# 95        NaN         NaN       NaN         NaN         False          0
# 96        NaN         NaN       NaN         NaN         False          0
# 97        NaN         NaN       NaN         NaN         False          0
# 98        NaN         NaN       NaN         NaN         False          0
# 99        NaN         NaN       NaN         NaN         False          0
# 100       NaN         NaN       NaN         NaN         False          0
# 101       NaN         NaN       NaN         NaN         False          0
# 102       NaN         NaN       NaN         NaN         False          0
# 103       NaN         NaN       NaN         NaN         False          0
# ..        ...         ...       ...         ...           ...        ...
# 544       NaN         NaN       NaN         NaN         False          6
# 545       NaN         NaN       NaN         NaN         False          6
# 546       NaN         NaN       NaN         NaN         False          6
# 547       NaN         NaN       NaN         NaN         False          6
# 548       NaN         NaN       NaN         NaN         False          6
# 549       NaN         NaN       NaN         NaN         False          6
# 550       NaN         NaN       NaN         NaN         False          6
# 551       NaN         NaN       NaN         NaN         False          6
# 552       NaN         NaN       NaN         NaN         False          6
# 553       NaN         NaN       NaN         NaN         False          6
# 554       NaN         NaN       NaN         NaN         False          6
# 555       NaN         NaN       NaN         NaN         False          6
# 556       NaN         NaN       NaN         NaN          True          7
# 557       NaN         NaN       NaN         NaN         False          7
# 558       NaN         NaN       NaN         NaN         False          7
# 559       NaN         NaN       NaN         NaN         False          7
# 560       NaN         NaN       NaN         NaN         False          7
# 561       NaN         NaN       NaN         NaN         False          7
# 562       NaN         NaN       NaN         NaN         False          7
# 563       NaN         NaN       NaN         NaN         False          7
# 564       NaN         NaN       NaN         NaN         False          7
# 565       NaN         NaN       NaN         NaN         False          7
# 566       NaN         NaN       NaN         NaN         False          7
# 567       NaN         NaN       NaN         NaN         False          7
# 568       NaN         NaN       NaN         NaN         False          7
# 569       NaN         NaN       NaN         NaN         False          7
# 570       NaN         NaN       NaN         NaN         False          7
# 571       NaN         NaN       NaN         NaN         False          7
# 572       NaN         NaN       NaN         NaN         False          7
# 573       NaN         NaN       NaN         NaN         False          7
#
#      Forced-Choice Trial
# 74                 False
# 75                 False
# 76                 False
# 77                 False
# 78                 False
# 79                 False
# 80                 False
# 81                 False
# 82                 False
# 83                 False
# 84                 False
# 85                 False
# 86                 False
# 87                 False
# 88                 False
# 89                 False
# 90                 False
# 91                 False
# 92                 False
# 93                 False
# 94                 False
# 95                 False
# 96                 False
# 97                 False
# 98                 False
# 99                 False
# 100                False
# 101                False
# 102                False
# 103                False
# ..                   ...
# 544                False
# 545                False
# 546                False
# 547                False
# 548                False
# 549                False
# 550                False
# 551                False
# 552                False
# 553                False
# 554                False
# 555                False
# 556                 True
# 557                False
# 558                False
# 559                False
# 560                False
# 561                False
# 562                False
# 563                False
# 564                False
# 565                False
# 566                False
# 567                False
# 568                False
# 569                False
# 570                False
# 571                False
# 572                False
# 573                False
#
# [500 rows x 20 columns]

# %%
#Logic for indicating whether a trial is a free choice, adds a column to the data frame (data) that returns a value of 1 for free-choice trials, 0 for all other instances
is_free_trial = (data.Item_Name == "Free-Choice Trials begin")
data["Free-Choice Trial"] = is_free_trial
is_free_trial.value_counts()

# %%
is_large_rew = (data.Arg1_Value == 0.3)
data["Large_Rew"] = is_large_rew

# %%
is_small_rew = (data.Arg1_Value == 1.2)
data["Small_Rew"] = is_small_rew

# %%
is_session_1 = (data.Item_Name == "Session1") & (data.Arg1_Value == 1)
data["Session_1"] = is_session_1

# %%
trial_1 = data.loc[
                                (data["trial_num"] == 1) &
                                (data["trial_end"] == 0)
]

# %%
trial_1.head(100)
# Out:
#      Evnt_Time  Evnt_ID                   Evnt_Name  \
# 147     60.893        1             Condition Event
# 148     60.893        4            Output Off Event
# 149     60.893       32     Whisker - Display Image
# 150     60.893       29                 Timer Event
# 151     60.893       32     Whisker - Display Image
# 152     60.893       21          Group Change Event
# 153     60.899       39  Input Transition Off Event
# 154     61.237       38   Input Transition On Event
# 155     62.046       39  Input Transition Off Event
# 156     62.438       38   Input Transition On Event
# 157     62.483       39  Input Transition Off Event
# 158     62.506       38   Input Transition On Event
# 159     62.534       39  Input Transition Off Event
# 160     62.922       38   Input Transition On Event
# 161     62.985       39  Input Transition Off Event
# 162     77.729       30            Touch Down Event
# 163     77.730        1             Condition Event
# 164     77.730        3             Output On Event
#
#                                  Item_Name  Alias_Name  Group_ID  Num_Args  \
# 147             Forced-Choice Trials Begin         NaN         7         0
# 148                           TrayLight #1         NaN         7         0
# 149  Bussey Mouse Operant Mode 2 x 1 x low      Images         7         2
# 150                     Presentation_timer         NaN         7         1
# 151  Bussey Mouse Operant Mode 2 x 1 x low  Background         7         2
# 152                           Group Change         NaN         7         1
# 153                             FIRBeam #1         NaN         9         0
# 154                             FIRBeam #1         NaN         9         0
# 155                                Tray #1         NaN         9         0
# 156                                Tray #1         NaN         9         0
# 157                                Tray #1         NaN         9         0
# 158                                Tray #1         NaN         9         0
# 159                                Tray #1         NaN         9         0
# 160                                Tray #1         NaN         9         0
# 161                                Tray #1         NaN         9         0
# 162  Bussey Mouse Operant Mode 2 x 1 x low         NaN         9         2
# 163            S1-Forced-image touch=small         NaN         9         0
# 164                           TrayLight #1         NaN         9         0
#
#      Arg1_Name  Arg1_Value Arg2_Name  ...  Arg3_Name Arg3_Value  Arg4_Name  \
# 147        NaN         NaN       NaN  ...        NaN        NaN        NaN
# 148        NaN         NaN       NaN  ...        NaN        NaN        NaN
# 149   Position         2.0   Image 1  ...        NaN        NaN        NaN
# 150      Value         0.0       NaN  ...        NaN        NaN        NaN
# 151   Position         1.0   Image 1  ...        NaN        NaN        NaN
# 152  New Group         9.0       NaN  ...        NaN        NaN        NaN
# 153        NaN         NaN       NaN  ...        NaN        NaN        NaN
# 154        NaN         NaN       NaN  ...        NaN        NaN        NaN
# 155        NaN         NaN       NaN  ...        NaN        NaN        NaN
# 156        NaN         NaN       NaN  ...        NaN        NaN        NaN
# 157        NaN         NaN       NaN  ...        NaN        NaN        NaN
# 158        NaN         NaN       NaN  ...        NaN        NaN        NaN
# 159        NaN         NaN       NaN  ...        NaN        NaN        NaN
# 160        NaN         NaN       NaN  ...        NaN        NaN        NaN
# 161        NaN         NaN       NaN  ...        NaN        NaN        NaN
# 162   Position         2.0   Image 1  ...        NaN        NaN        NaN
# 163        NaN         NaN       NaN  ...        NaN        NaN        NaN
# 164        NaN         NaN       NaN  ...        NaN        NaN        NaN
#
#     Arg4_Value  Arg5_Name Arg5_Value  is_new_trial  trial_num  is_trial_end  \
# 147        NaN        NaN        NaN          True          1         False
# 148        NaN        NaN        NaN         False          1         False
# 149        NaN        NaN        NaN         False          1         False
# 150        NaN        NaN        NaN         False          1         False
# 151        NaN        NaN        NaN         False          1         False
# 152        NaN        NaN        NaN         False          1         False
# 153        NaN        NaN        NaN         False          1         False
# 154        NaN        NaN        NaN         False          1         False
# 155        NaN        NaN        NaN         False          1         False
# 156        NaN        NaN        NaN         False          1         False
# 157        NaN        NaN        NaN         False          1         False
# 158        NaN        NaN        NaN         False          1         False
# 159        NaN        NaN        NaN         False          1         False
# 160        NaN        NaN        NaN         False          1         False
# 161        NaN        NaN        NaN         False          1         False
# 162        NaN        NaN        NaN         False          1         False
# 163        NaN        NaN        NaN         False          1         False
# 164        NaN        NaN        NaN         False          1         False
#
#      trial_end
# 147          0
# 148          0
# 149          0
# 150          0
# 151          0
# 152          0
# 153          0
# 154          0
# 155          0
# 156          0
# 157          0
# 158          0
# 159          0
# 160          0
# 161          0
# 162          0
# 163          0
# 164          0
#
# [18 rows x 21 columns]

# %%
#filter just the trials where is_trial_end is true
data["is_new_trial"].head()
# Out:
#      Evnt_Time  Evnt_ID        Evnt_Name                   Item_Name  \
# 147     60.893        1  Condition Event  Forced-Choice Trials Begin
# 236     89.491        1  Condition Event  Forced-Choice Trials Begin
# 296    102.515        1  Condition Event  Forced-Choice Trials Begin
# 368    115.703        1  Condition Event  Forced-Choice Trials Begin
# 428    153.728        1  Condition Event  Forced-Choice Trials Begin
#
#     Alias_Name  Group_ID  Num_Args Arg1_Name  Arg1_Value Arg2_Name  ...  \
# 147        NaN         7         0       NaN         NaN       NaN  ...
# 236        NaN         7         0       NaN         NaN       NaN  ...
# 296        NaN         7         0       NaN         NaN       NaN  ...
# 368        NaN         7         0       NaN         NaN       NaN  ...
# 428        NaN         7         0       NaN         NaN       NaN  ...
#
#      Arg3_Name Arg3_Value  Arg4_Name Arg4_Value  Arg5_Name Arg5_Value  \
# 147        NaN        NaN        NaN        NaN        NaN        NaN
# 236        NaN        NaN        NaN        NaN        NaN        NaN
# 296        NaN        NaN        NaN        NaN        NaN        NaN
# 368        NaN        NaN        NaN        NaN        NaN        NaN
# 428        NaN        NaN        NaN        NaN        NaN        NaN
#
#      is_new_trial  trial_num  is_trial_end  trial_end
# 147          True          1         False          0
# 236          True          2         False          1
# 296          True          3         False          2
# 368          True          4         False          3
# 428          True          5         False          4
#
# [5 rows x 21 columns]

# %%
# data["Item_Name"].value_counts()

# %%
session1 = (data.Item_Name == "Session1") & (data.Arg1_Value == 1)
session2 = (data.Item_Name == "Session2") & (data.Arg1_Value == 1)
session3 = (data.Item_Name == "Session3") & (data.Arg1_Value == 1)

# %%
data["session_1"] = session1
data["session_2"] = session2
data["session_3"] = session3

# %%
mult_cond2 = data.loc[
                        (data["session_1"] == "True") |
                        (data["num_col1"] > 50)
                   ]
mult_cond2.tail(2)

# %%
data["session_1"]
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29       True
#         ...
# 9635    False
# 9636    False
# 9637    False
# 9638    False
# 9639    False
# 9640    False
# 9641    False
# 9642    False
# 9643    False
# 9644    False
# 9645    False
# 9646    False
# 9647    False
# 9648    False
# 9649    False
# 9650    False
# 9651    False
# 9652    False
# 9653    False
# 9654    False
# 9655    False
# 9656    False
# 9657    False
# 9658    False
# 9659    False
# 9660    False
# 9661    False
# 9662    False
# 9663    False
# 9664    False
# Name: session_1, Length: 9665, dtype: bool

# %%
data["session_1"].value_counts()
# Out:
# 31    7624
# 5      127
# 9      103
# 1      102
# 2       88
# 8       75
# 4       73
# 18      70
# 27      68
# 22      65
# 13      65
# 15      63
# 26      62
# 23      61
# 25      61
# 29      60
# 24      60
# 7       60
# 6       60
# 3       60
# 14      59
# 21      59
# 12      59
# 20      59
# 10      57
# 17      57
# 16      57
# 28      57
# 19      56
# 30      56
# 11      53
# 0       29
# Name: session_1, dtype: int64

# %%
data["session_num"] = np.cumsum(data[any("session_")])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-867cbee0707d> in <module>
# ----> 1 data["session_num"] = np.cumsum(data[any("session_")])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True

# %%
session_1.head(200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-d5e8c8c6c58a> in <module>
# ----> 1 session_1.head(200)
#
# NameError: name 'session_1' is not defined

# %%
large_rew = data.Arg1_Value == 1.2

# %%
small_rew = data.Arg1_Value == 0.3

# %%
forced_trials = data.
# Out:
#   File "<ipython-input-32-73396d61b701>", line 1
#     forced_trials = data.
#                          ^
# SyntaxError: invalid syntax
