# %%
'''

This code is designed to filter data from a .csv file generated by ABET software based upon user input

Generating a data table and filtering is the first step to aligning behavioral epochs with calcium imaging data

'''

# %%
import pandas as pd
import numpy as np

# %%
# read in behavioral data as .csv
# eventually will write this more flexibly as a function (so users can give a filename externally)
data = pd.read_csv("74 12042019.csv")

# %%
# large_rew = data.Arg1_Value == 0.3

# %%
# forced_trial = data.Group_ID == 9

# %%
# free_trial = data.Group_ID == 12

# %%
# filtered  = data[large_rew & free_trial]

# %%
#Time values < 0 are housekeeping variables reported by the software. Safe to filter these out so they do not get counted as trials, etc.
filter_time_zero = data.Evnt_Time != 0
filter_time_zero.values
data = data[filter_time_zero]

# %%
is_new_trial = (data.Item_Name == "Forced-Choice Trials Begin") | (data.Item_Name == "Free-Choice Trials begin")

# %%
is_forced_trial = (data.Item_Name == "Forced-Choice Trials Begin")

# %%
is_free_trial = (data.Item_Name == "Free-Choice Trials begin")

# %%
is_free_trial.value_counts()
# Out:
# False    9478
# True      113
# Name: Item_Name, dtype: int64

# %%
is_forced_trial.value_counts()
# Out:
# False    9540
# True       51
# Name: Item_Name, dtype: int64

# %%
data["is_new_trial"] = is_new_trial

# %%
data["is_new_trial"].value_counts()
# Out:
# False    9427
# True      164
# Name: is_new_trial, dtype: int64

# %%
data["trial_num"] = np.cumsum(data["is_new_trial"])

# %%
data["trial_num"].max()
# Out:
# 164

# %%
is_trial_end = (data.Item_Name == "Feeder #2") | (data['Item_Name'].str.contains("_omission")) | (data.Item_Name == "BlankSide_touch_during_ForcedTrial")

# %%
data["is_trial_end"] = is_trial_end

# %%
data["is_trial_end"].value_counts()
# Out:
# False    9427
# True      164
# Name: is_trial_end, dtype: int64

# %%
data["trial_end"] = np.cumsum(data["is_trial_end"])

# %%
trial_1 = data.loc[
                                (data["trial_num"] == 1) &
                                (data["trial_end"] == 0)
]

# %%
data.head(100)

# %%
trial_1.head(100)
# Out:
#      Evnt_Time  Evnt_ID                   Evnt_Name  \
# 147     60.893        1             Condition Event
# 148     60.893        4            Output Off Event
# 149     60.893       32     Whisker - Display Image
# 150     60.893       29                 Timer Event
# 151     60.893       32     Whisker - Display Image
# 152     60.893       21          Group Change Event
# 153     60.899       39  Input Transition Off Event
# 154     61.237       38   Input Transition On Event
# 155     62.046       39  Input Transition Off Event
# 156     62.438       38   Input Transition On Event
# 157     62.483       39  Input Transition Off Event
# 158     62.506       38   Input Transition On Event
# 159     62.534       39  Input Transition Off Event
# 160     62.922       38   Input Transition On Event
# 161     62.985       39  Input Transition Off Event
# 162     77.729       30            Touch Down Event
# 163     77.730        1             Condition Event
# 164     77.730        3             Output On Event
#
#                                  Item_Name  Alias_Name  Group_ID  Num_Args  \
# 147             Forced-Choice Trials Begin         NaN         7         0
# 148                           TrayLight #1         NaN         7         0
# 149  Bussey Mouse Operant Mode 2 x 1 x low      Images         7         2
# 150                     Presentation_timer         NaN         7         1
# 151  Bussey Mouse Operant Mode 2 x 1 x low  Background         7         2
# 152                           Group Change         NaN         7         1
# 153                             FIRBeam #1         NaN         9         0
# 154                             FIRBeam #1         NaN         9         0
# 155                                Tray #1         NaN         9         0
# 156                                Tray #1         NaN         9         0
# 157                                Tray #1         NaN         9         0
# 158                                Tray #1         NaN         9         0
# 159                                Tray #1         NaN         9         0
# 160                                Tray #1         NaN         9         0
# 161                                Tray #1         NaN         9         0
# 162  Bussey Mouse Operant Mode 2 x 1 x low         NaN         9         2
# 163            S1-Forced-image touch=small         NaN         9         0
# 164                           TrayLight #1         NaN         9         0
#
#      Arg1_Name  Arg1_Value Arg2_Name  ...  Arg3_Name Arg3_Value  Arg4_Name  \
# 147        NaN         NaN       NaN  ...        NaN        NaN        NaN
# 148        NaN         NaN       NaN  ...        NaN        NaN        NaN
# 149   Position         2.0   Image 1  ...        NaN        NaN        NaN
# 150      Value         0.0       NaN  ...        NaN        NaN        NaN
# 151   Position         1.0   Image 1  ...        NaN        NaN        NaN
# 152  New Group         9.0       NaN  ...        NaN        NaN        NaN
# 153        NaN         NaN       NaN  ...        NaN        NaN        NaN
# 154        NaN         NaN       NaN  ...        NaN        NaN        NaN
# 155        NaN         NaN       NaN  ...        NaN        NaN        NaN
# 156        NaN         NaN       NaN  ...        NaN        NaN        NaN
# 157        NaN         NaN       NaN  ...        NaN        NaN        NaN
# 158        NaN         NaN       NaN  ...        NaN        NaN        NaN
# 159        NaN         NaN       NaN  ...        NaN        NaN        NaN
# 160        NaN         NaN       NaN  ...        NaN        NaN        NaN
# 161        NaN         NaN       NaN  ...        NaN        NaN        NaN
# 162   Position         2.0   Image 1  ...        NaN        NaN        NaN
# 163        NaN         NaN       NaN  ...        NaN        NaN        NaN
# 164        NaN         NaN       NaN  ...        NaN        NaN        NaN
#
#     Arg4_Value  Arg5_Name Arg5_Value  is_new_trial  trial_num  is_trial_end  \
# 147        NaN        NaN        NaN          True          1         False
# 148        NaN        NaN        NaN         False          1         False
# 149        NaN        NaN        NaN         False          1         False
# 150        NaN        NaN        NaN         False          1         False
# 151        NaN        NaN        NaN         False          1         False
# 152        NaN        NaN        NaN         False          1         False
# 153        NaN        NaN        NaN         False          1         False
# 154        NaN        NaN        NaN         False          1         False
# 155        NaN        NaN        NaN         False          1         False
# 156        NaN        NaN        NaN         False          1         False
# 157        NaN        NaN        NaN         False          1         False
# 158        NaN        NaN        NaN         False          1         False
# 159        NaN        NaN        NaN         False          1         False
# 160        NaN        NaN        NaN         False          1         False
# 161        NaN        NaN        NaN         False          1         False
# 162        NaN        NaN        NaN         False          1         False
# 163        NaN        NaN        NaN         False          1         False
# 164        NaN        NaN        NaN         False          1         False
#
#      trial_end
# 147          0
# 148          0
# 149          0
# 150          0
# 151          0
# 152          0
# 153          0
# 154          0
# 155          0
# 156          0
# 157          0
# 158          0
# 159          0
# 160          0
# 161          0
# 162          0
# 163          0
# 164          0
#
# [18 rows x 21 columns]

# %% [raw]
# #filter just the trials where is_trial_end is true
# data[is_new_trial].head()

# %%
# data["Item_Name"].value_counts()

# %%
data.head(200)
# Out:
#      Evnt_Time  Evnt_ID                          Evnt_Name  \
# 74       0.022        1                    Condition Event
# 75       0.022        3                    Output On Event
# 76       0.022        3                    Output On Event
# 77       0.022        3                    Output On Event
# 78       0.022        3                    Output On Event
# 79       0.022       21                 Group Change Event
# 80       0.035       39         Input Transition Off Event
# 81       0.047       38          Input Transition On Event
# 82       2.327       38          Input Transition On Event
# 83       2.443       39         Input Transition Off Event
# 84       2.493       38          Input Transition On Event
# 85       3.167       39         Input Transition Off Event
# 86       3.195       38          Input Transition On Event
# 87       3.211       39         Input Transition Off Event
# 88       6.924       38          Input Transition On Event
# 89       7.084       39         Input Transition Off Event
# 90       7.095       38          Input Transition On Event
# 91       8.315       39         Input Transition Off Event
# 92       8.321       38          Input Transition On Event
# 93       8.331       39         Input Transition Off Event
# 94       8.510       38          Input Transition On Event
# 95       8.571       39         Input Transition Off Event
# 96       8.597       38          Input Transition On Event
# 97       8.614       39         Input Transition Off Event
# 98      15.645       38          Input Transition On Event
# 99      15.724       39         Input Transition Off Event
# 100     15.806       38          Input Transition On Event
# 101     16.601       39         Input Transition Off Event
# 102     31.823       38          Input Transition On Event
# 103     32.093       39         Input Transition Off Event
# ..         ...      ...                                ...
# 244     89.935       39         Input Transition Off Event
# 245     92.805       30                   Touch Down Event
# 246     92.805        1                    Condition Event
# 247     92.805        3                    Output On Event
# 248     92.805        7                 Pulse Output Event
# 249     92.805        7                 Pulse Output Event
# 250     92.805       34  Whisker - Clear Image by Position
# 251     92.805       32            Whisker - Display Image
# 252     92.805       32            Whisker - Display Image
# 253     92.805       16                     Variable Event
# 254     92.805       19           List Change - Next Value
# 255     92.805       16                     Variable Event
# 256     92.805       16                     Variable Event
# 257     92.805       16                     Variable Event
# 258     92.805       21                 Group Change Event
# 259     92.805        1                    Condition Event
# 260     92.805       21                 Group Change Event
# 261     92.945       31                     Touch Up Event
# 262     93.812       39         Input Transition Off Event
# 263     93.818       38          Input Transition On Event
# 264     94.179       38          Input Transition On Event
# 265     94.180        1                    Condition Event
# 266     94.180        4                   Output Off Event
# 267     94.180       29                        Timer Event
# 268     94.180       19           List Change - Next Value
# 269     94.180       21                 Group Change Event
# 270    102.180        1                    Condition Event
# 271    102.180       16                     Variable Event
# 272    102.180       16                     Variable Event
# 273    102.180       21                 Group Change Event
#
#                                  Item_Name  Alias_Name  Group_ID  Num_Args  \
# 74                  set HL, WN_Off, Sound2         NaN         0         0
# 75                           HouseLight #1         NaN         0         0
# 76                                Sound #2         NaN         0         0
# 77                      White_Noise_Off #1         NaN         0         0
# 78                                Laser #1         NaN         0         0
# 79                            Group Change         NaN         0         1
# 80                              FIRBeam #1         NaN         2         0
# 81                              FIRBeam #1         NaN         2         0
# 82                                 Tray #1         NaN         2         0
# 83                                 Tray #1         NaN         2         0
# 84                                 Tray #1         NaN         2         0
# 85                                 Tray #1         NaN         2         0
# 86                                 Tray #1         NaN         2         0
# 87                                 Tray #1         NaN         2         0
# 88                                 Tray #1         NaN         2         0
# 89                                 Tray #1         NaN         2         0
# 90                                 Tray #1         NaN         2         0
# 91                                 Tray #1         NaN         2         0
# 92                                 Tray #1         NaN         2         0
# 93                                 Tray #1         NaN         2         0
# 94                                 Tray #1         NaN         2         0
# 95                                 Tray #1         NaN         2         0
# 96                                 Tray #1         NaN         2         0
# 97                                 Tray #1         NaN         2         0
# 98                                 Tray #1         NaN         2         0
# 99                                 Tray #1         NaN         2         0
# 100                                Tray #1         NaN         2         0
# 101                                Tray #1         NaN         2         0
# 102                                Tray #1         NaN         2         0
# 103                                Tray #1         NaN         2         0
# ..                                     ...         ...       ...       ...
# 244                                Tray #1         NaN         9         0
# 245  Bussey Mouse Operant Mode 2 x 1 x low         NaN         9         2
# 246              S1-Forced-image touch=big         NaN         9         0
# 247                           TrayLight #1         NaN         9         0
# 248                              Feeder #2         NaN         9         1
# 249                            Sound_On #1         NaN         9         1
# 250  Bussey Mouse Operant Mode 2 x 1 x low         NaN         9         2
# 251  Bussey Mouse Operant Mode 2 x 1 x low  Background         9         2
# 252  Bussey Mouse Operant Mode 2 x 1 x low  Background         9         2
# 253                           shock_on_off         NaN         9         1
# 254                S1_0_forcedchoice_shock         NaN         9         2
# 255                         _Trial_Counter         NaN         9         1
# 256            trial_withinsession_counter         NaN         9         1
# 257                  BigRew_forced_counter         NaN         9         1
# 258                           Group Change         NaN         9         1
# 259                      Don't Pulse Shock         NaN        14         0
# 260                           Group Change         NaN        14         1
# 261  Bussey Mouse Operant Mode 2 x 1 x low         NaN        17         2
# 262                             FIRBeam #1         NaN        17         0
# 263                             FIRBeam #1         NaN        17         0
# 264                                Tray #1         NaN        17         0
# 265         Reward Retrieved Forced Choice         NaN        17         0
# 266                           TrayLight #1         NaN        17         0
# 267                              ITI_timer         NaN        17         1
# 268                    ForcedGrid_Position         NaN        17         2
# 269                           Group Change         NaN        17         1
# 270                          ITI (regular)         NaN        21         0
# 271                              ITI_timer         NaN        21         1
# 272                              ITI_timer         NaN        21         1
# 273                           Group Change         NaN        21         1
#
#      Arg1_Name  Arg1_Value Arg2_Name  Arg2_Value Arg3_Name  Arg3_Value  \
# 74         NaN         NaN       NaN         NaN       NaN         NaN
# 75         NaN         NaN       NaN         NaN       NaN         NaN
# 76         NaN         NaN       NaN         NaN       NaN         NaN
# 77         NaN         NaN       NaN         NaN       NaN         NaN
# 78         NaN         NaN       NaN         NaN       NaN         NaN
# 79   New Group         2.0       NaN         NaN       NaN         NaN
# 80         NaN         NaN       NaN         NaN       NaN         NaN
# 81         NaN         NaN       NaN         NaN       NaN         NaN
# 82         NaN         NaN       NaN         NaN       NaN         NaN
# 83         NaN         NaN       NaN         NaN       NaN         NaN
# 84         NaN         NaN       NaN         NaN       NaN         NaN
# 85         NaN         NaN       NaN         NaN       NaN         NaN
# 86         NaN         NaN       NaN         NaN       NaN         NaN
# 87         NaN         NaN       NaN         NaN       NaN         NaN
# 88         NaN         NaN       NaN         NaN       NaN         NaN
# 89         NaN         NaN       NaN         NaN       NaN         NaN
# 90         NaN         NaN       NaN         NaN       NaN         NaN
# 91         NaN         NaN       NaN         NaN       NaN         NaN
# 92         NaN         NaN       NaN         NaN       NaN         NaN
# 93         NaN         NaN       NaN         NaN       NaN         NaN
# 94         NaN         NaN       NaN         NaN       NaN         NaN
# 95         NaN         NaN       NaN         NaN       NaN         NaN
# 96         NaN         NaN       NaN         NaN       NaN         NaN
# 97         NaN         NaN       NaN         NaN       NaN         NaN
# 98         NaN         NaN       NaN         NaN       NaN         NaN
# 99         NaN         NaN       NaN         NaN       NaN         NaN
# 100        NaN         NaN       NaN         NaN       NaN         NaN
# 101        NaN         NaN       NaN         NaN       NaN         NaN
# 102        NaN         NaN       NaN         NaN       NaN         NaN
# 103        NaN         NaN       NaN         NaN       NaN         NaN
# ..         ...         ...       ...         ...       ...         ...
# 244        NaN         NaN       NaN         NaN       NaN         NaN
# 245   Position         1.0   Image 1         0.0       NaN         NaN
# 246        NaN         NaN       NaN         NaN       NaN         NaN
# 247        NaN         NaN       NaN         NaN       NaN         NaN
# 248   Duration         1.2       NaN         NaN       NaN         NaN
# 249   Duration         1.0       NaN         NaN       NaN         NaN
# 250   Position         1.0       NaN        -1.0       NaN         NaN
# 251   Position         2.0   Image 1         0.0       NaN         NaN
# 252   Position         1.0   Image 1         0.0       NaN         NaN
# 253      Value         0.0       NaN         NaN       NaN         NaN
# 254      Index         4.0     Value         0.0       NaN         NaN
# 255      Value         3.0       NaN         NaN       NaN         NaN
# 256      Value         3.0       NaN         NaN       NaN         NaN
# 257      Value         1.0       NaN         NaN       NaN         NaN
# 258  New Group        14.0       NaN         NaN       NaN         NaN
# 259        NaN         NaN       NaN         NaN       NaN         NaN
# 260  New Group        17.0       NaN         NaN       NaN         NaN
# 261   Position         1.0   Image 1         0.0       NaN         NaN
# 262        NaN         NaN       NaN         NaN       NaN         NaN
# 263        NaN         NaN       NaN         NaN       NaN         NaN
# 264        NaN         NaN       NaN         NaN       NaN         NaN
# 265        NaN         NaN       NaN         NaN       NaN         NaN
# 266        NaN         NaN       NaN         NaN       NaN         NaN
# 267      Value         0.0       NaN         NaN       NaN         NaN
# 268      Index         1.0     Value         1.0       NaN         NaN
# 269  New Group        21.0       NaN         NaN       NaN         NaN
# 270        NaN         NaN       NaN         NaN       NaN         NaN
# 271      Value         8.0       NaN         NaN       NaN         NaN
# 272      Value         0.0       NaN         NaN       NaN         NaN
# 273  New Group         2.0       NaN         NaN       NaN         NaN
#
#     Arg4_Name  Arg4_Value Arg5_Name  Arg5_Value  is_new_trial
# 74        NaN         NaN       NaN         NaN         False
# 75        NaN         NaN       NaN         NaN         False
# 76        NaN         NaN       NaN         NaN         False
# 77        NaN         NaN       NaN         NaN         False
# 78        NaN         NaN       NaN         NaN         False
# 79        NaN         NaN       NaN         NaN         False
# 80        NaN         NaN       NaN         NaN         False
# 81        NaN         NaN       NaN         NaN         False
# 82        NaN         NaN       NaN         NaN         False
# 83        NaN         NaN       NaN         NaN         False
# 84        NaN         NaN       NaN         NaN         False
# 85        NaN         NaN       NaN         NaN         False
# 86        NaN         NaN       NaN         NaN         False
# 87        NaN         NaN       NaN         NaN         False
# 88        NaN         NaN       NaN         NaN         False
# 89        NaN         NaN       NaN         NaN         False
# 90        NaN         NaN       NaN         NaN         False
# 91        NaN         NaN       NaN         NaN         False
# 92        NaN         NaN       NaN         NaN         False
# 93        NaN         NaN       NaN         NaN         False
# 94        NaN         NaN       NaN         NaN         False
# 95        NaN         NaN       NaN         NaN         False
# 96        NaN         NaN       NaN         NaN         False
# 97        NaN         NaN       NaN         NaN         False
# 98        NaN         NaN       NaN         NaN         False
# 99        NaN         NaN       NaN         NaN         False
# 100       NaN         NaN       NaN         NaN         False
# 101       NaN         NaN       NaN         NaN         False
# 102       NaN         NaN       NaN         NaN         False
# 103       NaN         NaN       NaN         NaN         False
# ..        ...         ...       ...         ...           ...
# 244       NaN         NaN       NaN         NaN         False
# 245       NaN         NaN       NaN         NaN         False
# 246       NaN         NaN       NaN         NaN         False
# 247       NaN         NaN       NaN         NaN         False
# 248       NaN         NaN       NaN         NaN         False
# 249       NaN         NaN       NaN         NaN         False
# 250       NaN         NaN       NaN         NaN         False
# 251       NaN         NaN       NaN         NaN         False
# 252       NaN         NaN       NaN         NaN         False
# 253       NaN         NaN       NaN         NaN         False
# 254       NaN         NaN       NaN         NaN         False
# 255       NaN         NaN       NaN         NaN         False
# 256       NaN         NaN       NaN         NaN         False
# 257       NaN         NaN       NaN         NaN         False
# 258       NaN         NaN       NaN         NaN         False
# 259       NaN         NaN       NaN         NaN         False
# 260       NaN         NaN       NaN         NaN         False
# 261       NaN         NaN       NaN         NaN         False
# 262       NaN         NaN       NaN         NaN         False
# 263       NaN         NaN       NaN         NaN         False
# 264       NaN         NaN       NaN         NaN         False
# 265       NaN         NaN       NaN         NaN         False
# 266       NaN         NaN       NaN         NaN         False
# 267       NaN         NaN       NaN         NaN         False
# 268       NaN         NaN       NaN         NaN         False
# 269       NaN         NaN       NaN         NaN         False
# 270       NaN         NaN       NaN         NaN         False
# 271       NaN         NaN       NaN         NaN         False
# 272       NaN         NaN       NaN         NaN         False
# 273       NaN         NaN       NaN         NaN         False
#
# [200 rows x 18 columns]

# %%
session_1 = (data.Item_Name == "Session1") & (data.Arg1_Value == 1)
session_2 = (data.Item_Name == "Session2") & (data.Arg1_Value == 1)
session_3 = (data.Item_Name == "Session3") & (data.Arg1_Value == 1)

# %%
data["session_1"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'session_1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-6def562954ce> in <module>
# ----> 1 data["session_1"].value_counts()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'session_1'

# %%
data["session_num"] = np.cumsum(data["session_1"],data["session_2", data["session_3"]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'session_1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-8b6db7fcca80> in <module>
# ----> 1 data["session_num"] = np.cumsum(data["session_1"],data["session_2", data["session_3"]])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'session_1'

# %%
# Out:
# 1

# %%
data["session_num"] = np.cumsum(data[any("session_")])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-867cbee0707d> in <module>
# ----> 1 data["session_num"] = np.cumsum(data[any("session_")])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True

# %%
session_1.head(200)
# Out:
# 74     False
# 75     False
# 76     False
# 77     False
# 78     False
# 79     False
# 80     False
# 81     False
# 82     False
# 83     False
# 84     False
# 85     False
# 86     False
# 87     False
# 88     False
# 89     False
# 90     False
# 91     False
# 92     False
# 93     False
# 94     False
# 95     False
# 96     False
# 97     False
# 98     False
# 99     False
# 100    False
# 101    False
# 102    False
# 103    False
#        ...
# 244    False
# 245    False
# 246    False
# 247    False
# 248    False
# 249    False
# 250    False
# 251    False
# 252    False
# 253    False
# 254    False
# 255    False
# 256    False
# 257    False
# 258    False
# 259    False
# 260    False
# 261    False
# 262    False
# 263    False
# 264    False
# 265    False
# 266    False
# 267    False
# 268    False
# 269    False
# 270    False
# 271    False
# 272    False
# 273    False
# Length: 200, dtype: bool

# %%
large_rew = data.Arg1_Value == 1.2

# %%
small_rew = data.Arg1_Value == 0.3

# %%
forced_trials = data.
