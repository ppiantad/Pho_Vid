# %%
'''

This code is designed to filter data from a .csv file generated by ABET software based upon user input

Generating a data table and filtering is the first step to aligning behavioral epochs with calcium imaging data

'''

# %%
pwd
# Out:
# 'C:\\Users\\Patrick\\Pho_Vid'

# %%
import pandas as pd
import numpy as np

# %%
# read in behavioral data as .csv
# eventually will write this more flexibly as a function (so users can give a filename externally)
data = pd.read_csv("74 12042019.csv")

# %%
#Time values < 0 are housekeeping variables reported by the software. Safe to filter these out so they do not get counted as trials, etc.
filter_time_zero = data.Evnt_Time != 0
filter_time_zero.values
data = data[filter_time_zero]

# %%
#logic for indicating new trials, adds a new column to the data frame (data) that counts the number of trials based on trial starts
is_new_trial = (data.Item_Name == "Forced-Choice Trials Begin") | (data.Item_Name == "Free-Choice Trials begin")
data["is_new_trial"] = is_new_trial
data["is_new_trial"].value_counts()
data["trial_num"] = np.cumsum(data["is_new_trial"])
data["trial_num"].max()
# Out:
# 164

# %%
#Logic for indicating whether a trial is a forced choice, adds a column to the data frame (data) that returns a value of 1 for forced choice trials, 0 for everything else
is_forced_trial = (data.Item_Name == "Forced-Choice Trials Begin") 
is_forced_trial.value_counts()
# Out:
# False    9540
# True       51
# Name: Item_Name, dtype: int64

# %%
#Logic for indicating whether a trial is a free choice, adds a column to the data frame (data) that returns a value of 1 for free-choice trials, 0 for all other instances
is_free_trial = (data.Item_Name == "Free-Choice Trials begin")
is_free_trial.value_counts()
data["Free-Choice Trials"] =

# %%
#logic for indicating trial ends, 
is_trial_end = (data.Item_Name == "Feeder #2") | (data['Item_Name'].str.contains("_omission")) | (data.Item_Name == "BlankSide_touch_during_ForcedTrial")
data["is_trial_end"] = is_trial_end
data["is_trial_end"].value_counts()
data["trial_end"] = np.cumsum(data["is_trial_end"])
data["trial_end"].max()
# Out:
# 164

# %%
trial_1 = data.loc[
                                (data["trial_num"] == 1) &
                                (data["trial_end"] == 0)
]

# %%
#filter just the trials where is_trial_end is true
data[is_new_trial].head()
# Out:
#      Evnt_Time  Evnt_ID        Evnt_Name                   Item_Name  \
# 147     60.893        1  Condition Event  Forced-Choice Trials Begin
# 236     89.491        1  Condition Event  Forced-Choice Trials Begin
# 296    102.515        1  Condition Event  Forced-Choice Trials Begin
# 368    115.703        1  Condition Event  Forced-Choice Trials Begin
# 428    153.728        1  Condition Event  Forced-Choice Trials Begin
#
#     Alias_Name  Group_ID  Num_Args Arg1_Name  Arg1_Value Arg2_Name  ...  \
# 147        NaN         7         0       NaN         NaN       NaN  ...
# 236        NaN         7         0       NaN         NaN       NaN  ...
# 296        NaN         7         0       NaN         NaN       NaN  ...
# 368        NaN         7         0       NaN         NaN       NaN  ...
# 428        NaN         7         0       NaN         NaN       NaN  ...
#
#      Arg3_Name Arg3_Value  Arg4_Name Arg4_Value  Arg5_Name Arg5_Value  \
# 147        NaN        NaN        NaN        NaN        NaN        NaN
# 236        NaN        NaN        NaN        NaN        NaN        NaN
# 296        NaN        NaN        NaN        NaN        NaN        NaN
# 368        NaN        NaN        NaN        NaN        NaN        NaN
# 428        NaN        NaN        NaN        NaN        NaN        NaN
#
#      is_new_trial  trial_num  is_trial_end  trial_end
# 147          True          1         False          0
# 236          True          2         False          1
# 296          True          3         False          2
# 368          True          4         False          3
# 428          True          5         False          4
#
# [5 rows x 21 columns]

# %%
# data["Item_Name"].value_counts()

# %%
session1 = (data.Item_Name == "Session1") & (data.Arg1_Value == 1)
session2 = (data.Item_Name == "Session2") & (data.Arg1_Value == 1)
session3 = (data.Item_Name == "Session3") & (data.Arg1_Value == 1)

# %%
data["session1b"] = np.cumsum(data["session1"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'session1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-d0ede2845ff8> in <module>
# ----> 1 data["session1b"] = np.cumsum(data["session1"])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'session1'

# %%
data["session_num"] = np.cumsum(data[any("session_")])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-867cbee0707d> in <module>
# ----> 1 data["session_num"] = np.cumsum(data[any("session_")])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True

# %%
session_1.head(200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-d5e8c8c6c58a> in <module>
# ----> 1 session_1.head(200)
#
# NameError: name 'session_1' is not defined

# %%
large_rew = data.Arg1_Value == 1.2

# %%
small_rew = data.Arg1_Value == 0.3

# %%
forced_trials = data.
# Out:
#   File "<ipython-input-32-73396d61b701>", line 1
#     forced_trials = data.
#                          ^
# SyntaxError: invalid syntax
